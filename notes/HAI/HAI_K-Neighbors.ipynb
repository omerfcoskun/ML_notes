# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('test2.csv')

# %%
df
# Out:
#                        time  P1_B2004  P1_B2016   P1_B3004    P1_B3005  \
# 0       2020-07-09 15:00:00   0.09874   1.25036  382.21698  1118.61084
# 1       2020-07-09 15:00:01   0.09874   1.24944  382.21698  1118.61084
# 2       2020-07-09 15:00:02   0.09874   1.24746  382.21698  1118.61084
# 3       2020-07-09 15:00:03   0.09874   1.24624  382.21698  1118.61084
# 4       2020-07-09 15:00:04   0.09874   1.24364  382.21698  1118.61084
# ...                     ...       ...       ...        ...         ...
# 118796  2020-07-10 23:59:56   0.10121   1.30608  397.63785  1001.99799
# 118797  2020-07-10 23:59:57   0.10121   1.30226  397.63785  1001.99799
# 118798  2020-07-10 23:59:58   0.10121   1.29707  397.63785  1001.99799
# 118799  2020-07-10 23:59:59   0.10121   1.29906  397.63785  1001.99799
# 118800  2020-07-11 00:00:00   0.10121   1.29784  397.63785  1001.99799
#
#         P1_B4002   P1_B4005    P1_B400B  P1_B4022  P1_FCV01D  ...  P4_ST_GOV  \
# ...

# %%
df.columns
# Out:
# Index(['time', 'P1_B2004', 'P1_B2016', 'P1_B3004', 'P1_B3005', 'P1_B4002',
#        'P1_B4005', 'P1_B400B', 'P1_B4022', 'P1_FCV01D', 'P1_FCV01Z',
#        'P1_FCV02D', 'P1_FCV02Z', 'P1_FCV03D', 'P1_FCV03Z', 'P1_FT01',
#        'P1_FT01Z', 'P1_FT02', 'P1_FT02Z', 'P1_FT03', 'P1_FT03Z', 'P1_LCV01D',
#        'P1_LCV01Z', 'P1_LIT01', 'P1_PCV01D', 'P1_PCV01Z', 'P1_PCV02D',
#        'P1_PCV02Z', 'P1_PIT01', 'P1_PIT02', 'P1_PP01AD', 'P1_PP01AR',
#        'P1_PP01BD', 'P1_PP01BR', 'P1_PP02D', 'P1_PP02R', 'P1_STSP', 'P1_TIT01',
#        'P1_TIT02', 'P2_24Vdc', 'P2_ASD', 'P2_AutoGO', 'P2_CO_rpm', 'P2_Emerg',
#        'P2_HILout', 'P2_MSD', 'P2_ManualGO', 'P2_OnOff', 'P2_RTR', 'P2_SIT01',
#        'P2_SIT02', 'P2_TripEx', 'P2_VT01', 'P2_VTR01', 'P2_VTR02', 'P2_VTR03',
#        'P2_VTR04', 'P2_VXT02', 'P2_VXT03', 'P2_VYT02', 'P2_VYT03', 'P3_FIT01',
#        'P3_LCP01D', 'P3_LCV01D', 'P3_LH', 'P3_LIT01', 'P3_LL', 'P3_PIT01',
# ...

# %%
df.drop(['time','P2_24Vdc', 'P2_ASD', 'P2_AutoGO', 'P2_CO_rpm', 'P2_Emerg',
       'P2_HILout', 'P2_MSD', 'P2_ManualGO', 'P2_OnOff', 'P2_RTR', 'P2_SIT01',
       'P2_SIT02', 'P2_TripEx', 'P2_VT01', 'P2_VTR01', 'P2_VTR02', 'P2_VTR03',
       'P2_VTR04', 'P2_VXT02', 'P2_VXT03', 'P2_VYT02', 'P2_VYT03', 'P3_FIT01',
       'P3_LCP01D', 'P3_LCV01D', 'P3_LH', 'P3_LIT01', 'P3_LL', 'P3_PIT01',
       'P4_HT_FD', 'P4_HT_LD', 'P4_HT_PO', 'P4_HT_PS', 'P4_LD', 'P4_ST_FD',
       'P4_ST_GOV', 'P4_ST_LD', 'P4_ST_PO', 'P4_ST_PS', 'P4_ST_PT01',
       'P4_ST_TT01', 'attack', 'attack_P2', 'attack_P3'],axis=1,inplace=True)

# %%
df
# Out:
#         P1_B2004  P1_B2016   P1_B3004    P1_B3005  P1_B4002   P1_B4005  \
# 0        0.09874   1.25036  382.21698  1118.61084   32.0000   99.98731
# 1        0.09874   1.24944  382.21698  1118.61084   32.0000  100.00000
# 2        0.09874   1.24746  382.21698  1118.61084   32.0000   99.98115
# 3        0.09874   1.24624  382.21698  1118.61084   32.0000  100.00000
# 4        0.09874   1.24364  382.21698  1118.61084   32.0000  100.00000
# ...          ...       ...        ...         ...       ...        ...
# 118796   0.10121   1.30608  397.63785  1001.99799   33.6555  100.00000
# 118797   0.10121   1.30226  397.63785  1001.99799   33.6555  100.00000
# 118798   0.10121   1.29707  397.63785  1001.99799   33.6555  100.00000
# 118799   0.10121   1.29906  397.63785  1001.99799   33.6555  100.00000
# 118800   0.10121   1.29784  397.63785  1001.99799   33.6555  100.00000
#
#           P1_B400B  P1_B4022  P1_FCV01D  P1_FCV01Z  ...  P1_PP01AD  P1_PP01AR  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118801 entries, 0 to 118800
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   P1_B2004   118801 non-null  float64
#  1   P1_B2016   118801 non-null  float64
#  2   P1_B3004   118801 non-null  float64
#  3   P1_B3005   118801 non-null  float64
#  4   P1_B4002   118801 non-null  float64
#  5   P1_B4005   118801 non-null  float64
#  6   P1_B400B   118801 non-null  float64
#  7   P1_B4022   118801 non-null  float64
#  8   P1_FCV01D  118801 non-null  float64
#  9   P1_FCV01Z  118801 non-null  float64
#  10  P1_FCV02D  118801 non-null  float64
#  11  P1_FCV02Z  118801 non-null  float64
#  12  P1_FCV03D  118801 non-null  float64
#  13  P1_FCV03Z  118801 non-null  float64
#  14  P1_FT01    118801 non-null  float64
#  15  P1_FT01Z   118801 non-null  float64
#  16  P1_FT02    118801 non-null  float64
#  17  P1_FT02Z   118801 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# P1_B2004     0
# P1_B2016     0
# P1_B3004     0
# P1_B3005     0
# P1_B4002     0
# P1_B4005     0
# P1_B400B     0
# P1_B4022     0
# P1_FCV01D    0
# P1_FCV01Z    0
# P1_FCV02D    0
# P1_FCV02Z    0
# P1_FCV03D    0
# P1_FCV03Z    0
# P1_FT01      0
# P1_FT01Z     0
# P1_FT02      0
# P1_FT02Z     0
# P1_FT03      0
# P1_FT03Z     0
# P1_LCV01D    0
# P1_LCV01Z    0
# P1_LIT01     0
# P1_PCV01D    0
# P1_PCV01Z    0
# P1_PCV02D    0
# P1_PCV02Z    0
# P1_PIT01     0
# P1_PIT02     0
# P1_PP01AD    0
# P1_PP01AR    0
# P1_PP01BD    0
# P1_PP01BR    0
# P1_PP02D     0
# P1_PP02R     0
# P1_STSP      0
# P1_TIT01     0
# P1_TIT02     0
# attack_P1    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# P1_B2004     0
# P1_B2016     0
# P1_B3004     0
# P1_B3005     0
# P1_B4002     0
# P1_B4005     0
# P1_B400B     0
# P1_B4022     0
# P1_FCV01D    0
# P1_FCV01Z    0
# P1_FCV02D    0
# P1_FCV02Z    0
# P1_FCV03D    0
# P1_FCV03Z    0
# P1_FT01      0
# P1_FT01Z     0
# P1_FT02      0
# P1_FT02Z     0
# P1_FT03      0
# P1_FT03Z     0
# P1_LCV01D    0
# P1_LCV01Z    0
# P1_LIT01     0
# P1_PCV01D    0
# P1_PCV01Z    0
# P1_PCV02D    0
# P1_PCV02Z    0
# P1_PIT01     0
# P1_PIT02     0
# P1_PP01AD    0
# P1_PP01AR    0
# P1_PP01BD    0
# P1_PP01BR    0
# P1_PP02D     0
# P1_PP02R     0
# P1_STSP      0
# P1_TIT01     0
# P1_TIT02     0
# attack_P1    0
# dtype: int64

# %%
df['attack_P1'].value_counts()
# Out:
# 0    116387
# 1      2414
# Name: attack_P1, dtype: int64

# %%
correlation = df.corr()

# %%
correlation['attack_P1'].sort_values(ascending=False)
# Out:
# attack_P1    1.000000
# P1_LCV01D    0.337706
# P1_LCV01Z    0.332530
# P1_PCV02D    0.214098
# P1_PCV02Z    0.213513
# P1_FT01      0.137043
# P1_TIT02     0.045445
# P1_TIT01     0.036984
# P1_PIT02     0.027453
# P1_FT02Z     0.024070
# P1_B400B     0.024045
# P1_B4005     0.021066
# P1_FT02      0.016250
# P1_FT03      0.014762
# P1_B3005     0.013714
# P1_B4022     0.012090
# P1_B4002     0.010213
# P1_FT03Z     0.009291
# P1_B2016     0.006943
# P1_PIT01     0.004005
# P1_FCV03D    0.003370
# P1_FCV01D    0.001023
# P1_FCV01Z    0.001012
# P1_FCV03Z   -0.004981
# P1_PCV01D   -0.016979
# P1_PCV01Z   -0.017688
# P1_FCV02D   -0.024296
# P1_B3004    -0.026654
# P1_FCV02Z   -0.035027
# P1_B2004    -0.048626
# P1_FT01Z    -0.049031
# P1_LIT01    -0.171784
# P1_PP01AD         NaN
# P1_PP01AR         NaN
# P1_PP01BD         NaN
# P1_PP01BR         NaN
# P1_PP02D          NaN
# P1_PP02R          NaN
# P1_STSP           NaN
# Name: attack_P1, dtype: float64

# %%
X=df.drop(['attack_P1'],axis=1)
y=df['attack_P1']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape,X_test.shape
# Out:
# ((95040, 38), (23761, 38))

# %%
X_train.dtypes
# Out:
# P1_B2004     float64
# P1_B2016     float64
# P1_B3004     float64
# P1_B3005     float64
# P1_B4002     float64
# P1_B4005     float64
# P1_B400B     float64
# P1_B4022     float64
# P1_FCV01D    float64
# P1_FCV01Z    float64
# P1_FCV02D    float64
# P1_FCV02Z    float64
# P1_FCV03D    float64
# P1_FCV03Z    float64
# P1_FT01      float64
# P1_FT01Z     float64
# P1_FT02      float64
# P1_FT02Z     float64
# P1_FT03      float64
# P1_FT03Z     float64
# P1_LCV01D    float64
# P1_LCV01Z    float64
# P1_LIT01     float64
# P1_PCV01D    float64
# P1_PCV01Z    float64
# P1_PCV02D    float64
# P1_PCV02Z    float64
# P1_PIT01     float64
# P1_PIT02     float64
# P1_PP01AD      int64
# P1_PP01AR      int64
# P1_PP01BD      int64
# P1_PP01BR      int64
# P1_PP02D       int64
# P1_PP02R       int64
# P1_STSP        int64
# P1_TIT01     float64
# P1_TIT02     float64
# dtype: object

# %%
X_train.isnull().sum()
# Out:
# P1_B2004     0
# P1_B2016     0
# P1_B3004     0
# P1_B3005     0
# P1_B4002     0
# P1_B4005     0
# P1_B400B     0
# P1_B4022     0
# P1_FCV01D    0
# P1_FCV01Z    0
# P1_FCV02D    0
# P1_FCV02Z    0
# P1_FCV03D    0
# P1_FCV03Z    0
# P1_FT01      0
# P1_FT01Z     0
# P1_FT02      0
# P1_FT02Z     0
# P1_FT03      0
# P1_FT03Z     0
# P1_LCV01D    0
# P1_LCV01Z    0
# P1_LIT01     0
# P1_PCV01D    0
# P1_PCV01Z    0
# P1_PCV02D    0
# P1_PCV02Z    0
# P1_PIT01     0
# P1_PIT02     0
# P1_PP01AD    0
# P1_PP01AR    0
# P1_PP01BD    0
# P1_PP01BR    0
# P1_PP02D     0
# P1_PP02R     0
# P1_STSP      0
# P1_TIT01     0
# P1_TIT02     0
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# P1_B2004     0
# P1_B2016     0
# P1_B3004     0
# P1_B3005     0
# P1_B4002     0
# P1_B4005     0
# P1_B400B     0
# P1_B4022     0
# P1_FCV01D    0
# P1_FCV01Z    0
# P1_FCV02D    0
# P1_FCV02Z    0
# P1_FCV03D    0
# P1_FCV03Z    0
# P1_FT01      0
# P1_FT01Z     0
# P1_FT02      0
# P1_FT02Z     0
# P1_FT03      0
# P1_FT03Z     0
# P1_LCV01D    0
# P1_LCV01Z    0
# P1_LIT01     0
# P1_PCV01D    0
# P1_PCV01Z    0
# P1_PCV02D    0
# P1_PCV02Z    0
# P1_PIT01     0
# P1_PIT02     0
# P1_PP01AD    0
# P1_PP01AR    0
# P1_PP01BD    0
# P1_PP01BR    0
# P1_PP02D     0
# P1_PP02R     0
# P1_STSP      0
# P1_TIT01     0
# P1_TIT02     0
# dtype: int64

# %%
cols=X_train.columns

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

X_train=scaler.fit_transform(X_train)

X_test=scaler.transform(X_test)

# %%
X_train=pd.DataFrame(X_train,columns=[cols])

X_test=pd.DataFrame(X_test,columns=[cols])

# %%
X_train
# Out:
#        P1_B2004  P1_B2016  P1_B3004  P1_B3005  P1_B4002  P1_B4005  P1_B400B  \
# 0      0.908638  1.448614 -0.067747 -1.508157  1.563372  0.786873  0.731246
# 1      0.908638 -1.591339 -0.067747 -1.508157  1.563372  0.786873  0.728476
# 2      0.271074 -0.013009 -0.222960  0.632246  0.024430  0.021529  0.222656
# 3     -1.283533  0.989171 -1.281894  0.393125 -0.885180 -1.156888 -1.163545
# 4      1.039644  0.304475  0.909165  0.429312 -1.462908 -0.795462 -0.806786
# ...         ...       ...       ...       ...       ...       ...       ...
# 95035  0.271074 -1.238967 -0.222960  0.632246  0.024430 -0.208536 -0.190223
# 95036  0.908638 -2.276579 -0.067747 -1.508157  1.563372  0.786873  0.739052
# 95037  0.271074  1.232995 -0.222960  0.632246  0.024430 -0.858170 -0.796490
# 95038  0.271074 -1.011305 -0.222960  0.632246  0.024430 -1.167743 -1.110105
# 95039 -1.641617 -0.613401  0.860078  0.377957 -0.682152 -1.473992 -1.546534
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=knn.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
#K=3 için doğruluk
print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score: 0.9989

# %%
#eğitim seti için  doğruluk
y_pred_train = knn.predict(X_train)

print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Out:
# Training-set accuracy score: 0.9997

# %%
#K=2 için doğruluk
knn_2 = KNeighborsClassifier(n_neighbors=2)

knn_2.fit(X_train, y_train)

y_pred_2 = knn_2.predict(X_test)


print('Model accuracy score with k=2 : {0:0.4f}'. format(accuracy_score(y_test, y_pred_2)))
# Out:
# Model accuracy score with k=2 : 0.9991

# %%
#K=3 için konfüzyon matrisi
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print('Confusion matrix\n\n', cm)

print('\nTrue Positives(TP) = ', cm[0,0])

print('\nTrue Negatives(TN) = ', cm[1,1])

print('\nFalse Positives(FP) = ', cm[0,1])

print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[23260    13]
#  [   12   476]]
#
# True Positives(TP) =  23260
#
# True Negatives(TN) =  476
#
# False Positives(FP) =  13
#
# False Negatives(FN) =  12

# %%
#K=2 için confizyon matrisi
cm_2 = confusion_matrix(y_test, y_pred_2)

print('Confusion matrix\n\n', cm_2)

print('\nTrue Positives(TP) = ', cm_2[0,0])

print('\nTrue Negatives(TN) = ', cm_2[1,1])

print('\nFalse Positives(FP) = ', cm_2[0,1])

print('\nFalse Negatives(FN) = ', cm_2[1,0])
# Out:
# Confusion matrix
#
#  [[23267     6]
#  [   16   472]]
#
# True Positives(TP) =  23267
#
# True Negatives(TN) =  472
#
# False Positives(FP) =  6
#
# False Negatives(FN) =  16

# %%
plt.figure(figsize=(6,4))

cm_matrix = pd.DataFrame(data=cm_7, columns=['Actual Positive:1', 'Actual Negative:0'], 
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <AxesSubplot:>
